# %%
# Initial imports
import os
import requests
import pandas as pd
import pandas_montecarlo
from MCForecastTools import MCSimulation
from pathlib import Path
import datetime as dt
import seaborn as sns
import numpy as np
import matplotlib.animation as ani


import matplotlib.pyplot as plt

# %matplotlib inline

# %%
#Set Params for plot in workbook 

plt.rcParams["figure.figsize"] = (11,6)

# %%
# Import Covid Data 
covid_data = Path("covid_cases_by_location.csv")
covid_data = pd.read_csv(covid_data, parse_dates=True, infer_datetime_format=True)

# %%
#view pd dataframe 
covid_data.head()
# Out:
#   notification_date postcode lhd_2010_code         lhd_2010_name lga_code19  \
# 0        2020-01-25     2134          X700                Sydney      11300
# 1        2020-01-25     2121          X760       Northern Sydney      16260
# 2        2020-01-25     2071          X760       Northern Sydney      14500
# 3        2020-01-27     2033          X720  South Eastern Sydney      16550
# 4        2020-03-01     2163          X710  South Western Sydney      12850
#
#         lga_name19
# 0      Burwood (A)
# 1   Parramatta (C)
# 2  Ku-ring-gai (A)
# 3     Randwick (C)
# 4    Fairfield (C)

# %%
#Set notification_date as index 

covid_data['notification_date'] = pd.to_datetime(covid_data['notification_date'])

covid_data = covid_data.set_index('notification_date')

#covid_data.drop(['notification_date'], axis =1)
covid_data
# Out:
#                   postcode lhd_2010_code         lhd_2010_name lga_code19  \
# notification_date
# 2020-01-25            2134          X700                Sydney      11300
# 2020-01-25            2121          X760       Northern Sydney      16260
# 2020-01-25            2071          X760       Northern Sydney      14500
# 2020-01-27            2033          X720  South Eastern Sydney      16550
# 2020-03-01            2163          X710  South Western Sydney      12850
# ...                    ...           ...                   ...        ...
# 2021-08-31            2165          X710  South Western Sydney      12850
# 2021-08-31            2500          X730  Illawarra Shoalhaven      18450
# 2021-08-31            2142          X740        Western Sydney      12380
# 2021-08-31            2171          X710  South Western Sydney      14900
# 2021-08-31            2161          X740        Western Sydney      12380
#
#                         lga_name19
# notification_date
# 2020-01-25             Burwood (A)
# 2020-01-25          Parramatta (C)
# 2020-01-25         Ku-ring-gai (A)
# 2020-01-27            Randwick (C)
# 2020-03-01           Fairfield (C)
# ...                            ...
# 2021-08-31           Fairfield (C)
# 2021-08-31          Wollongong (C)
# 2021-08-31          Cumberland (A)
# 2021-08-31           Liverpool (C)
# 2021-08-31          Cumberland (A)
#
# [27922 rows x 5 columns]

# %%
#Create Covid count by day
covid_by_day = covid_data['postcode'].groupby(covid_data['postcode'].index.date).count()

covid_by_day
# Out:
# 2020-01-25       3
# 2020-01-27       1
# 2020-03-01       2
# 2020-03-02       3
# 2020-03-03       6
#               ...
# 2021-08-27    1135
# 2021-08-28    1135
# 2021-08-29    1212
# 2021-08-30    1099
# 2021-08-31     941
# Name: postcode, Length: 526, dtype: int64

# %%
#Graph Covid_by_data data 

covid_count_plt = covid_by_day.plot(figsize=(30,12), title='Daily Covid Cases')

covid_count_plt.set(ylabel='Number of Cases', xlabel='Days')

#plt.axhline(y=0.0, color='g', alpha=0.5, linestyle='--')  
#plt.show()
# Out:
# [Text(0, 0.5, 'Number of Cases'), Text(0.5, 0, 'Days')]

# %%
# Determine the Standard Deviation for the last 14 days of Covid Data 
covid_by_day['Change']= covid_by_day['close'].pct_change().fillna(0)
std_14 = covid_by_day['Change'].tail(14).std()
std_14
# Out:
# 0.1091329154856369

# %%
mean_14 = covid_by_day['Change'].tail(14).mean()
mean_14
# Out:
# 0.04477503539839672

# %%
#Set variables for MC Sim 

projected_days = 10   #number of days to project out from last day of actual data

num_simulations = 50  #number of simulations required 


daily_changes = np.random.normal(mean_14,std_14,(projected_days,num_simulations))

# %%
#Create projection dataframe 
projection = pd.DataFrame((daily_changes + 1).cumprod(axis = 0) * 941)
projection
# Out:
#             0            1            2            3            4   \
# 0  1044.344624  1139.283784   989.279788  1036.738487  1110.992329
# 1  1080.874407  1350.874354  1049.162033  1054.039194  1156.367670
# 2  1144.525765  1409.508095  1048.461440   930.949331  1377.068428
# 3  1464.625180  1494.858033   966.128774   967.171279  1596.950104
# 4  1398.087127  1462.909198  1030.772797   946.117718  1488.834445
# 5  1288.900968  1189.124398   964.604220   846.985651  1805.582380
# 6  1403.045546  1558.600290   780.983950   872.165438  2186.709060
# 7  1545.223684  1375.278897   764.773585   828.399999  2184.914736
# 8  1545.072850  1476.529229   735.212971   882.600739  2584.030926
# 9  1411.294815  1593.010896   770.976752   941.465462  2642.644640
#
#             5            6            7            8            9   ...  \
# 0   982.246303   977.144153  1029.700840   927.327025  1011.991284  ...
# 1  1004.090078   923.628260  1028.758579   984.529778  1233.796829  ...
# 2  1052.639648  1087.610843  1167.053245   990.498025  1291.634019  ...
# 3  1025.404621   883.299442  1143.370787  1148.628805  1507.647529  ...
# 4  1206.907295   801.944405  1170.064762  1083.255730  1775.642207  ...
# 5  1230.886938   881.337709  1207.694525  1295.189431  1512.651448  ...
# 6  1324.023276   988.751096  1283.763430  1149.426144  1364.857405  ...
# 7  1266.270194  1227.808077  1391.901409  1188.763829  1424.210445  ...
# 8  1369.266935  1333.812506  1073.676452  1180.701436  1490.852267  ...
# 9  1300.832722  1526.383245  1050.896138  1305.556925  1654.789150  ...
#
#             40          41          42           43           44           45  \
# 0  1060.931481  988.430566  928.295675  1003.795191  1107.508544  1086.808397
# 1  1208.908791  755.791785  935.072509  1144.766107  1261.275420  1187.179725
# 2  1320.343394  746.517999  775.542123  1088.845900  1448.858163  1392.101568
# 3  1382.460509  741.546101  857.152455  1198.117463  1788.376624  1370.861851
# 4  1149.329861  671.913998  961.426724  1177.319677  2129.979500  1598.354741
# 5  1332.817791  775.098978  840.331007  1279.399550  2150.700981  1641.385426
# 6  1248.181837  666.634892  850.421727  1381.709997  2261.301309  1934.128881
# 7  1329.017669  655.892697  811.744488  1185.558635  2093.551465  2183.952410
# 8  1567.170808  618.403907  886.778137  1314.714044  1853.377804  2136.684638
# 9  1716.289729  651.273303  954.357913  1515.168194  1753.731300  2617.580960
#
#             46           47           48           49
# 0  1045.307486  1040.759871   959.660394   758.644424
# 1  1067.190357  1175.547929   983.584747   881.506723
# 2  1137.409062  1228.136706   897.291640  1030.206728
# 3  1160.893543  1341.357730   804.308973  1034.188194
# 4  1116.686535  1458.130252  1013.415647  1116.044286
# 5  1176.401001  1304.058983   782.515512   984.760067
# 6  1239.879122  1245.288883   909.646920  1032.465169
# 7  1374.130289  1303.304780   860.895839   965.198225
# 8  1400.005665  1522.773454   962.991870  1032.706792
# 9  1333.049666  1627.266996   951.530835  1078.876242
#
# [10 rows x 50 columns]

# %%
#Plot Projection Scenarios 
projection.plot(figsize=(30,12), title='Project Daily Cases').set(ylabel='Projected Number of Cases', xlabel='Projected Days')
# Out:
# [Text(0, 0.5, 'Projected Number of Cases'), Text(0.5, 0, 'Projected Days')]

# %%
# Out:
# <AxesSubplot:title={'center':'Project Daily Cases'}, xlabel='Projected Days', ylabel='Projected Number of Cases'>

# %%
#Graph Covid_by_data data 

covid_count_plt = covid_by_day.plot(figsize=(30,12), title='Daily Covid Cases')
covid_count_plt.set(ylabel='Number of Cases')
#plt.axhline(y=0.0, color='k', alpha=0.5, linestyle='--')  
color = ['red']







fig = plt.figure()


#plt.show()

# %%
def buildmebarchart(i=int):
    plt.legend(projection.columns)
    p = plt.plot(df1[:i].index, df1[:i].values) #note it only returns the dataset, up to the point i
    for i in range(0,4):
        p[i].set_color(color[i]) #set the colour of each curve
import matplotlib.animation as ani
animator = ani.FuncAnimation(fig, buildmebarchart, interval = 100)
plt.show()

# %%
animator = ani.FuncAnimation(fig, chartfunc, interval = 100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-16f3b32179ff> in <module>
# ----> 1 animator = ani.FuncAnimation(fig, chartfunc, interval = 100)
#
# NameError: name 'chartfunc' is not defined
